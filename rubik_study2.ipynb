# %%
#初期化
from rubik import *
from time import sleep

# %%
#画面が消えてしまったとき
init()

# %%
#リスト表示をするか否か (Trueで表示、Falseで非表示)
list_view(True)

# %%
shuffle()

# %% [markdown]
# ### while文
#
# 条件を満たす間同じ操作を繰り返す

# %%
x = 2
while x < 1000 :
    print(x)
    x = x * x

# %%
n = 100
while not n == 1 :
    if n % 2 == 0 :
        n = n // 2
    else :
        n = 3 * n + 1
    print(n)

# %%
while cube()[5][0][1] == "W" :
    D()
print(cube()[5][0][1])

# %%
while not cube()[5][0][1] == "W" :
    D()
print(cube()[5][0][1])

# %%
Di()
F2()

# %% [markdown]
# ここまででできることの例
# * 底面に4つのエッジの白マスが揃っている状態からクロスまで
# * 底面のすでに揃っている白マスを避けてサイドや上面の白マスを揃える
# * クロスを揃えるプログラム
